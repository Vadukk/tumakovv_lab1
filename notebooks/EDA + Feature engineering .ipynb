# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import os

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
pd.set_option('display.max_columns', 500)

# %% [markdown]
# # EDA

# %%
raw_path = '../data/raw/'
train = pd.read_csv(os.path.join(raw_path, 'train.csv'))
test = pd.read_csv(os.path.join(raw_path, 'test.csv'))

# %%
train.sample(4)
# Out:
#                 ID Пол                      Семья        Этнос Национальность  \
# 468  54-503-013-01   Ж             вдовец / вдова  европейская        Русские
# 954  54-702-016-01   М  в браке в настоящее время  европейская        Русские
# 857  54-601-002-01   Ж             вдовец / вдова  европейская        Русские
# 22   54-501-011-01   Ж  в браке в настоящее время  европейская        Русские
#
#           Религия                   Образование  \
# 468  Христианство  4 - профессиональное училище
# 954  Христианство  4 - профессиональное училище
# 857  Христианство                       5 - ВУЗ
# 22   Христианство  4 - профессиональное училище
#
#                                              Профессия  Вы работаете?  \
# 468                      техники и младшие специалисты              0
# 954  операторы и монтажники установок и машинного о...              1
# 857                        дипломированные специалисты              0
# 22                       техники и младшие специалисты              1
#
#      Выход на пенсию  Прекращение работы по болезни  Сахарный диабет  Гепатит  \
# 468                1                              0                1        0
# 954                0                              0                0        0
# 857                1                              0                0        1
# 22                 0                              0                0        0
#
#      Онкология  Хроническое заболевание легких  Бронжиальная астма  \
# 468          0                               0                   0
# 954          0                               0                   0
# 857          0                               0                   0
# 22           0                               0                   0
#
#      Туберкулез легких   ВИЧ/СПИД  Регулярный прим лекарственных средств  \
# 468                   0         0                                      1
# 954                   0         0                                      0
# 857                   0         0                                      1
# 22                    0         0                                      1
#
#      Травмы за год  Переломы       Статус Курения  Возраст курения  \
# 468              0         0            Бросил(а)             35.0
# 954              0         1                Курит             10.0
# 857              0         1  Никогда не курил(а)              NaN
# 22               0         0  Никогда не курил(а)              NaN
#
#      Сигарет в день  Пассивное курение   Частота пасс кур  \
# 468             8.0                  0                NaN
# 954            30.0                  0                NaN
# 857             NaN                  1  1-2 раза в неделю
# 22              NaN                  1  1-2 раза в неделю
#
#                          Алкоголь  Возраст алког Время засыпания  \
# 468  употребляю в настоящее время           25.0        22:30:00
# 954  употребляю в настоящее время           17.0        22:00:00
# 857              ранее употреблял           22.0        23:00:00
# 22          никогда не употреблял            NaN        21:30:00
#
#     Время пробуждения  Сон после обеда  Спорт, клубы  Религия, клубы  \
# 468          09:00:00                0             0               0
# 954          05:00:00                1             0               0
# 857          06:00:00                0             0               0
# 22           06:00:00                0             0               0
#
#               ID_y  Артериальная гипертензия  ОНМК  \
# 468  54-503-013-01                         1     0
# 954  54-702-016-01                         0     0
# 857  54-601-002-01                         1     1
# 22   54-501-011-01                         0     0
#
#      Стенокардия, ИБС, инфаркт миокарда  Сердечная недостаточность  \
# 468                                   0                          0
# 954                                   0                          0
# 857                                   1                          1
# 22                                    0                          0
#
#      Прочие заболевания сердца
# 468                          1
# 954                          0
# 857                          0
# 22                           1

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 955 entries, 0 to 954
# Data columns (total 39 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   ID                                     955 non-null    object
#  1   Пол                                    954 non-null    object
#  2   Семья                                  955 non-null    object
#  3   Этнос                                  955 non-null    object
#  4   Национальность                         955 non-null    object
#  5   Религия                                955 non-null    object
#  6   Образование                            955 non-null    object
#  7   Профессия                              955 non-null    object
#  8   Вы работаете?                          955 non-null    int64
#  9   Выход на пенсию                        955 non-null    int64
#  10  Прекращение работы по болезни          955 non-null    int64
#  11  Сахарный диабет                        955 non-null    int64
#  12  Гепатит                                955 non-null    int64
#  13  Онкология                              955 non-null    int64
#  14  Хроническое заболевание легких         955 non-null    int64
#  15  Бронжиальная астма                     955 non-null    int64
#  16  Туберкулез легких                      955 non-null    int64
#  17  ВИЧ/СПИД                               955 non-null    int64
#  18  Регулярный прим лекарственных средств  955 non-null    int64
#  19  Травмы за год                          955 non-null    int64
#  20  Переломы                               955 non-null    int64
#  21  Статус Курения                         955 non-null    object
#  22  Возраст курения                        412 non-null    float64
#  23  Сигарет в день                         409 non-null    float64
#  24  Пассивное курение                      955 non-null    int64
#  25  Частота пасс кур                       223 non-null    object
#  26  Алкоголь                               955 non-null    object
#  27  Возраст алког                          788 non-null    float64
#  28  Время засыпания                        955 non-null    object
#  29  Время пробуждения                      955 non-null    object
#  30  Сон после обеда                        955 non-null    int64
#  31  Спорт, клубы                           955 non-null    int64
#  32  Религия, клубы                         955 non-null    int64
#  33  ID_y                                   955 non-null    object
#  34  Артериальная гипертензия               955 non-null    int64
#  35  ОНМК                                   955 non-null    int64
#  36  Стенокардия, ИБС, инфаркт миокарда     955 non-null    int64
#  37  Сердечная недостаточность              955 non-null    int64
#  38  Прочие заболевания сердца              955 non-null    int64
# dtypes: float64(3), int64(22), object(14)
# memory usage: 291.1+ KB

# %% [markdown]
# Подсмотрели небольшой препроцессинг для некоторых записей

# %%
train['Пол'].fillna('Ж', inplace=True)  # 54-701-009-01
train['Время засыпания'].replace('12:00:00', '00:00:00', inplace=True)  # 54-002-054-02
train.loc[train['Частота пасс кур'].isna() == False, 'Пассивное курение'] = 1  # 54-001-079-01

no_time = (train['Время засыпания'] == train['Время пробуждения'])
train.loc[no_time, ['Время засыпания']] = '23:00:00'
train.loc[no_time, ['Время пробуждения']] = '07:00:00'

# %%
test['Статус Курения'].replace('Никогда не курил', 'Никогда не курил(а)', inplace=True)  # 54-701-037-01
test['Время засыпания'].replace('09:00:00', '21:00:00', inplace=True)  # 54-602-001-01
test['Время засыпания'].replace('00:00:30', '00:30:00', inplace=True)  # 54-103-014-01
test['Время пробуждения'].replace('00:06:00', '06:00:00', inplace=True)

no_time = (test['Время засыпания'] == test['Время пробуждения'])
test.loc[no_time, ['Время засыпания']] = '23:00:00'
test.loc[no_time, ['Время пробуждения']] = '07:00:00'

# %% [markdown]
# ## Разберемся с пропусками

# %%
# train
for col in train.columns:
    if train[col].isna().sum() != 0:
        print(f'Колонка "{col}" имеет {train[col].isna().sum()} пропусков')
# Out:
# Колонка "Возраст курения" имеет 543 пропусков
# Колонка "Сигарет в день" имеет 546 пропусков
# Колонка "Частота пасс кур" имеет 732 пропусков
# Колонка "Возраст алког" имеет 167 пропусков

# %%
# test
for col in test.columns:
    if test[col].isna().sum() != 0:
        print(f'Колонка "{col}" имеет {test[col].isna().sum()} пропусков')
# Out:
# Колонка "Возраст курения" имеет 369 пропусков
# Колонка "Сигарет в день" имеет 373 пропусков
# Колонка "Частота пасс кур" имеет 484 пропусков
# Колонка "Возраст алког" имеет 137 пропусков

# %%
train.sample(10)
# Out:
#                 ID Пол                                      Семья  \
# 675  54-002-016-01   М  гражданский брак / проживание с партнером
# 516  54-002-067-01   Ж                  в браке в настоящее время
# 22   54-501-011-01   Ж                  в браке в настоящее время
# 389  54-002-173-01   Ж                  в браке в настоящее время
# 217  54-702-018-02   М                  в браке в настоящее время
# 66   54-103-099-01   Ж                             вдовец / вдова
# 24   54-102-097-01   Ж                             вдовец / вдова
# 642  54-103-067-01   Ж                             вдовец / вдова
# 61   54-501-091-01   Ж                  в браке в настоящее время
# 94   54-102-058-01   М                  в браке в настоящее время
#
#            Этнос Национальность            Религия  \
# 675  европейская        Русские       Христианство
# 516  европейская        Русские       Христианство
# 22   европейская        Русские       Христианство
# 389  европейская        Русские  Атеист / агностик
# 217  европейская        Русские       Христианство
# 66   европейская        Русские       Христианство
# 24   европейская        Русские       Христианство
# 642  европейская        Русские  Атеист / агностик
# 61   европейская        Русские       Христианство
# 94   европейская        Русские       Христианство
#
#                                            Образование  \
# 675                       4 - профессиональное училище
# 516                                            5 - ВУЗ
# 22                        4 - профессиональное училище
# 389                                            5 - ВУЗ
# 217                                            5 - ВУЗ
# 66                                             5 - ВУЗ
# 24                        4 - профессиональное училище
# 642  3 - средняя школа / закон.среднее / выше среднего
# 61   3 - средняя школа / закон.среднее / выше среднего
# 94                                             5 - ВУЗ
#
#                                              Профессия  Вы работаете?  \
# 675  операторы и монтажники установок и машинного о...              1
# 516                                           служащие              1
# 22                       техники и младшие специалисты              1
# 389                        дипломированные специалисты              1
# 217  ремесленники и представители других отраслей п...              1
# 66                         дипломированные специалисты              0
# 24                         ведение домашнего хозяйства              0
# 642                                           служащие              0
# 61                    низкоквалифицированные работники              1
# 94                         дипломированные специалисты              1
#
#      Выход на пенсию  Прекращение работы по болезни  Сахарный диабет  Гепатит  \
# 675                0                              0                0        0
# 516                0                              0                0        0
# 22                 0                              0                0        0
# 389                0                              0                0        0
# 217                0                              0                0        1
# 66                 1                              0                0        0
# 24                 1                              0                1        0
# 642                1                              0                0        0
# 61                 0                              0                0        0
# 94                 0                              0                0        0
#
#      Онкология  Хроническое заболевание легких  Бронжиальная астма  \
# 675          0                               0                   0
# 516          0                               0                   0
# 22           0                               0                   0
# 389          0                               0                   0
# 217          0                               0                   0
# 66           0                               0                   0
# 24           1                               0                   0
# 642          0                               0                   0
# 61           0                               0                   0
# 94           0                               0                   0
#
#      Туберкулез легких   ВИЧ/СПИД  Регулярный прим лекарственных средств  \
# 675                   0         0                                      0
# 516                   0         0                                      1
# 22                    0         0                                      1
# 389                   0         0                                      1
# 217                   0         0                                      0
# 66                    0         0                                      1
# 24                    0         0                                      1
# 642                   0         0                                      0
# 61                    0         0                                      0
# 94                    0         0                                      0
#
#      Травмы за год  Переломы       Статус Курения  Возраст курения  \
# 675              1         0                Курит             27.0
# 516              0         0  Никогда не курил(а)              NaN
# 22               0         0  Никогда не курил(а)              NaN
# 389              0         0  Никогда не курил(а)              NaN
# 217              0         1                Курит             21.0
# 66               0         0  Никогда не курил(а)              NaN
# 24               0         0  Никогда не курил(а)              NaN
# 642              0         0            Бросил(а)             16.0
# 61               0         0            Бросил(а)             20.0
# 94               0         1  Никогда не курил(а)              NaN
#
#      Сигарет в день  Пассивное курение   Частота пасс кур  \
# 675            20.0                  0                NaN
# 516             NaN                  0                NaN
# 22              NaN                  1  1-2 раза в неделю
# 389             NaN                  0                NaN
# 217            20.0                  0                NaN
# 66              NaN                  0                NaN
# 24              NaN                  0                NaN
# 642             4.0                  0                NaN
# 61              5.0                  1  1-2 раза в неделю
# 94              NaN                  1  1-2 раза в неделю
#
#                          Алкоголь  Возраст алког Время засыпания  \
# 675  употребляю в настоящее время           27.0        03:00:00
# 516         никогда не употреблял            NaN        00:30:00
# 22          никогда не употреблял            NaN        21:30:00
# 389  употребляю в настоящее время           17.0        23:30:00
# 217  употребляю в настоящее время           25.0        23:00:00
# 66   употребляю в настоящее время           18.0        23:00:00
# 24               ранее употреблял           16.0        00:00:00
# 642              ранее употреблял           18.0        00:00:00
# 61   употребляю в настоящее время           16.0        22:00:00
# 94   употребляю в настоящее время           17.0        01:00:00
#
#     Время пробуждения  Сон после обеда  Спорт, клубы  Религия, клубы  \
# 675          07:00:00                0             0               0
# 516          07:00:00                0             0               0
# 22           06:00:00                0             0               0
# 389          06:00:00                0             0               0
# 217          10:00:00                0             0               0
# 66           07:00:00                0             0               0
# 24           06:00:00                1             0               0
# 642          08:00:00                0             0               0
# 61           06:30:00                0             0               0
# 94           07:30:00                0             0               0
#
#               ID_y  Артериальная гипертензия  ОНМК  \
# 675  54-002-016-01                         0     0
# 516  54-002-067-01                         0     0
# 22   54-501-011-01                         0     0
# 389  54-002-173-01                         1     0
# 217  54-702-018-02                         0     0
# 66   54-103-099-01                         0     0
# 24   54-102-097-01                         1     1
# 642  54-103-067-01                         1     0
# 61   54-501-091-01                         1     0
# 94   54-102-058-01                         0     0
#
#      Стенокардия, ИБС, инфаркт миокарда  Сердечная недостаточность  \
# 675                                   0                          0
# 516                                   0                          0
# 22                                    0                          0
# 389                                   0                          0
# 217                                   0                          0
# 66                                    0                          0
# 24                                    0                          0
# 642                                   0                          0
# 61                                    0                          0
# 94                                    0                          0
#
#      Прочие заболевания сердца
# 675                          0
# 516                          0
# 22                           1
# 389                          1
# 217                          0
# 66                           0
# 24                           0
# 642                          0
# 61                           0
# 94                           0

# %% [markdown]
# Логично заметить, что все пропуски - это просто нулевые значения

# %%
train.fillna(0, inplace=True)

# %% [markdown]
# # Features

# %%
TARGETS = [
    'Артериальная гипертензия',
    'ОНМК',
    'Стенокардия, ИБС, инфаркт миокарда',
    'Сердечная недостаточность',
    'Прочие заболевания сердца',
]

# %%
features = train[['ID']].copy()

# %%
for target in TARGETS:
    features[target] = train[target] == 1

# %% [markdown]
# Мы будем обучать деревянную модель (Catboost), а значит нам лучше закодировать все признаки one-hot энкодингом

# %%
base_features = [
    ('Пол - М', 'Пол', ['М']),
    ('Семья - в браке в настоящее время', 'Семья', ['в браке в настоящее время']),
    ('Семья - в разводе', 'Семья', ['в разводе']),
    ('Семья - вдовец / вдова', 'Семья', ['вдовец / вдова']),
    ('Семья - гражданский брак / проживание с партнером', 'Семья', ['гражданский брак / проживание с партнером']),
    ('Семья - никогда не был(а) в браке', 'Семья', ['никогда не был(а) в браке']),
    ('Семья - раздельное проживание (официально не разведены)', 'Семья', ['раздельное проживание (официально не разведены)']),
    ('Семья - живет один', 'Семья', ['в разводе', 'вдовец / вдова', 'никогда не был(а) в браке', 'раздельное проживание (официально не разведены)']),
    ('Этнос - европейская', 'Этнос', ['европейская']),
    ('Этнос - другая азиатская', 'Этнос', ['другая азиатская (Корея, Малайзия, Таиланд, Вьетнам, Казахстан, Киргизия, Туркмения, Узбекистан, Таджикистан)']),
    ('Этнос - прочее', 'Этнос', ['прочее (любая иная этно-расовая группа, не представленная выше)']),
    ('Национальность - Азербайджанцы', 'Национальность', ['Азербайджанцы']),
    ('Национальность - Армяне', 'Национальность', ['Армяне']),
    ('Национальность - Башкиры', 'Национальность', ['Башкиры']),
    ('Национальность - Белорусы', 'Национальность', ['Белорусы']),
    ('Национальность - Буряты', 'Национальность', ['Буряты']),
    ('Национальность - Другие национальности', 'Национальность', ['Другие национальности']),
    ('Национальность - Евреи', 'Национальность', ['Евреи']),
    ('Национальность - Казахи', 'Национальность', ['Казахи']),
    ('Национальность - Киргизы', 'Национальность', ['Киргизы']),
    ('Национальность - Лезгины', 'Национальность', ['Лезгины']),
    ('Национальность - Молдаване', 'Национальность', ['Молдаване']),
    ('Национальность - Мордва', 'Национальность', ['Мордва']),
    ('Национальность - Немцы', 'Национальность', ['Немцы']),
    ('Национальность - Русские', 'Национальность', ['Русские']),
    ('Национальность - Таджики', 'Национальность', ['Таджики']),
    ('Национальность - Татары', 'Национальность', ['Татары']),
    ('Национальность - Удмурты', 'Национальность', ['Удмурты']),
    ('Национальность - Украинцы', 'Национальность', ['Украинцы']),
    ('Национальность - Чуваши', 'Национальность', ['Чуваши']),
    ('Национальность - Эстонцы', 'Национальность', ['Эстонцы']),
    ('Национальность - Азия / Кавказ', 'Национальность', ['Азербайджанцы', 'Армяне', 'Казахи', 'Киргизы', 'Лезгины', 'Таджики']),
    ('Национальность - Русские / Белорусы / Украинцы', 'Национальность', ['Русские', 'Белорусы', 'Украинцы']),
    ('Религия - Атеист / агностик', 'Религия', ['Атеист / агностик']),
    ('Религия - Другое', 'Религия', ['Другое']),
    ('Религия - Индуизм', 'Религия', ['Индуизм']),
    ('Религия - Ислам', 'Религия', ['Ислам']),
    ('Религия - Нет', 'Религия', ['Нет']),
    ('Религия - Христианство', 'Религия', ['Христианство']),
    ('Религия - Индуизм / Ислам / Другое', 'Религия', ['Индуизм', 'Ислам', 'Другое']),
    ('Религия - Верующий', 'Религия', ['Другое', 'Индуизм', 'Ислам', 'Христианство']),
    ('Образование - начальная школа', 'Образование', ['2 - начальная школа']),
    ('Образование - среднее', 'Образование', ['3 - средняя школа / закон.среднее / выше среднего']),
    ('Образование - профессиональное училище', 'Образование', ['4 - профессиональное училище']),
    ('Образование - ВУЗ', 'Образование', ['5 - ВУЗ']),
    ('Профессия - ведение домашнего хозяйства', 'Профессия', ['ведение домашнего хозяйства']),
    ('Профессия - вооруженные силы', 'Профессия', ['вооруженные силы']),
    ('Профессия - дипломированные специалисты', 'Профессия', ['дипломированные специалисты']),
    ('Профессия - квалифицированные работники сельского хозяйства и рыболовного', 'Профессия', ['квалифицированные работники сельского хозяйства и рыболовного']),
    ('Профессия - низкоквалифицированные работники', 'Профессия', ['низкоквалифицированные работники']),
    ('Профессия - операторы и монтажники установок и машинного оборудования', 'Профессия', ['операторы и монтажники установок и машинного оборудования']),
    ('Профессия - законотворцы / менеджеры', 'Профессия', ['представители   законодат.   органов   власти,  высокопостав. долж.лица и менеджеры']),
    ('Профессия - сфера обслуживания', 'Профессия', ['работники,  занятые в сфере обслуживания, торговые работники магазинов и рынков']),
    ('Профессия - ремесленники и представители других отраслей промышленности', 'Профессия', ['ремесленники и представители других отраслей промышленности']),
    ('Профессия - служащие', 'Профессия', ['служащие']),
    ('Профессия - техники и младшие специалисты', 'Профессия', ['техники и младшие специалисты']),
    ('Профессия - военные / служащие / управление', 'Профессия', ['вооруженные силы', 'представители   законодат.   органов   власти,  высокопостав. долж.лица и менеджеры', 'служащие']),
    ('Профессия - промышленность', 'Профессия', ['операторы и монтажники установок и машинного оборудования', 'ремесленники и представители других отраслей промышленности', 'техники и младшие специалисты']),
    ('Профессия - низкая квалификация', 'Профессия', ['низкоквалифицированные работники', 'ведение домашнего хозяйства']),
    ('Вы работаете?', 'Вы работаете?', [1]),
    ('Выход на пенсию', 'Выход на пенсию', [1]),
    ('Прекращение работы по болезни', 'Прекращение работы по болезни', [1]),
    ('Сахарный диабет', 'Сахарный диабет', [1]),
    ('Гепатит', 'Гепатит', [1]),
    ('Онкология', 'Онкология', [1]),
    ('Хроническое заболевание легких', 'Хроническое заболевание легких', [1]),
    ('Бронхиальная астма', 'Бронжиальная астма', [1]),
    ('Туберкулез легких', 'Туберкулез легких ', [1]),
    ('ВИЧ/СПИД', 'ВИЧ/СПИД', [1]),
    ('Регулярный прием лекарственных средств', 'Регулярный прим лекарственных средств', [1]),
    ('Травмы за год', 'Травмы за год', [1]),
    ('Переломы', 'Переломы', [1]),
    ('Статус Курения - Бросил(а)', 'Статус Курения', ['Бросил(а)']),
    ('Статус Курения - Курит', 'Статус Курения', ['Курит']),
    ('Статус Курения - Никогда не курил(а)', 'Статус Курения', ['Никогда не курил(а)']),
    ('Пассивное курение', 'Пассивное курение', [1]),
    ('Алкоголь - никогда не употреблял', 'Алкоголь', ['никогда не употреблял']),
    ('Алкоголь - ранее употреблял', 'Алкоголь', ['ранее употреблял']),
    ('Алкоголь - употребляю в настоящее время', 'Алкоголь', ['употребляю в настоящее время']),
    ('Сон после обеда', 'Сон после обеда', [1]),
    ('Спорт клубы', 'Спорт, клубы', [1]),
    ('Религия клубы', 'Религия, клубы', [1]),
]

for name, column, values in base_features:
    features[name] = train[column].isin(values)

# %%
features.sample(3)
# Out:
#                 ID  Артериальная гипертензия   ОНМК  \
# 305  54-001-040-01                      True   True
# 654  54-602-032-01                     False  False
# 808  54-501-064-01                      True  False
#
#      Стенокардия, ИБС, инфаркт миокарда  Сердечная недостаточность  \
# 305                               False                      False
# 654                               False                      False
# 808                               False                      False
#
#      Прочие заболевания сердца  Пол - М  Семья - в браке в настоящее время  \
# 305                      False    False                               True
# 654                      False     True                               True
# 808                      False     True                               True
#
#      Семья - в разводе  Семья - вдовец / вдова  \
# 305              False                   False
# 654              False                   False
# 808              False                   False
#
#      Семья - гражданский брак / проживание с партнером  \
# 305                                              False
# 654                                              False
# 808                                              False
#
#      Семья - никогда не был(а) в браке  \
# 305                              False
# 654                              False
# 808                              False
#
#      Семья - раздельное проживание (официально не разведены)  \
# 305                                              False
# 654                                              False
# 808                                              False
#
#      Семья - живет один  Этнос - европейская  Этнос - другая азиатская  \
# 305               False                 True                     False
# 654               False                 True                     False
# 808               False                 True                     False
#
#      Этнос - прочее  Национальность - Азербайджанцы  Национальность - Армяне  \
# 305           False                           False                    False
# 654           False                           False                    False
# 808           False                           False                    False
#
#      Национальность - Башкиры  Национальность - Белорусы  \
# 305                     False                      False
# 654                     False                      False
# 808                     False                      False
#
#      Национальность - Буряты  Национальность - Другие национальности  \
# 305                    False                                   False
# 654                    False                                   False
# 808                    False                                   False
#
#      Национальность - Евреи  Национальность - Казахи  \
# 305                   False                    False
# 654                   False                    False
# 808                   False                    False
#
#      Национальность - Киргизы  Национальность - Лезгины  \
# 305                     False                     False
# 654                     False                     False
# 808                     False                     False
#
#      Национальность - Молдаване  Национальность - Мордва  \
# 305                       False                    False
# 654                       False                    False
# 808                       False                    False
#
#      Национальность - Немцы  Национальность - Русские  \
# 305                   False                      True
# 654                   False                      True
# 808                   False                      True
#
#      Национальность - Таджики  Национальность - Татары  \
# 305                     False                    False
# 654                     False                    False
# 808                     False                    False
#
#      Национальность - Удмурты  Национальность - Украинцы  \
# 305                     False                      False
# 654                     False                      False
# 808                     False                      False
#
#      Национальность - Чуваши  Национальность - Эстонцы  \
# 305                    False                     False
# 654                    False                     False
# 808                    False                     False
#
#      Национальность - Азия / Кавказ  \
# 305                           False
# 654                           False
# 808                           False
#
#      Национальность - Русские / Белорусы / Украинцы  \
# 305                                            True
# 654                                            True
# 808                                            True
#
#      Религия - Атеист / агностик  Религия - Другое  Религия - Индуизм  \
# 305                        False             False              False
# 654                        False             False              False
# 808                        False             False              False
#
#      Религия - Ислам  Религия - Нет  Религия - Христианство  \
# 305            False          False                    True
# 654            False          False                    True
# 808            False          False                    True
#
#      Религия - Индуизм / Ислам / Другое  Религия - Верующий  \
# 305                               False                True
# 654                               False                True
# 808                               False                True
#
#      Образование - начальная школа  Образование - среднее  \
# 305                          False                  False
# 654                          False                   True
# 808                          False                  False
#
#      Образование - профессиональное училище  Образование - ВУЗ  \
# 305                                    True              False
# 654                                   False              False
# 808                                    True              False
#
#      Профессия - ведение домашнего хозяйства  Профессия - вооруженные силы  \
# 305                                    False                         False
# 654                                    False                         False
# 808                                    False                         False
#
#      Профессия - дипломированные специалисты  \
# 305                                     True
# 654                                    False
# 808                                    False
#
#      Профессия - квалифицированные работники сельского хозяйства и рыболовного  \
# 305                                              False
# 654                                              False
# 808                                              False
#
#      Профессия - низкоквалифицированные работники  \
# 305                                         False
# 654                                         False
# 808                                          True
#
#      Профессия - операторы и монтажники установок и машинного оборудования  \
# 305                                              False
# 654                                               True
# 808                                              False
#
#      Профессия - законотворцы / менеджеры  Профессия - сфера обслуживания  \
# 305                                 False                           False
# 654                                 False                           False
# 808                                 False                           False
#
#      Профессия - ремесленники и представители других отраслей промышленности  \
# 305                                              False
# 654                                              False
# 808                                              False
#
#      Профессия - служащие  Профессия - техники и младшие специалисты  \
# 305                 False                                      False
# 654                 False                                      False
# 808                 False                                      False
#
#      Профессия - военные / служащие / управление  Профессия - промышленность  \
# 305                                        False                       False
# 654                                        False                        True
# 808                                        False                       False
#
#      Профессия - низкая квалификация  Вы работаете?  Выход на пенсию  \
# 305                            False           True            False
# 654                            False           True            False
# 808                             True          False            False
#
#      Прекращение работы по болезни  Сахарный диабет  Гепатит  Онкология  \
# 305                          False            False    False      False
# 654                          False            False    False      False
# 808                          False            False    False      False
#
#      Хроническое заболевание легких  Бронхиальная астма  Туберкулез легких  \
# 305                           False               False              False
# 654                           False               False              False
# 808                            True               False               True
#
#      ВИЧ/СПИД  Регулярный прием лекарственных средств  Травмы за год  \
# 305     False                                    True          False
# 654     False                                   False          False
# 808     False                                    True          False
#
#      Переломы  Статус Курения - Бросил(а)  Статус Курения - Курит  \
# 305     False                       False                   False
# 654      True                       False                    True
# 808     False                       False                    True
#
#      Статус Курения - Никогда не курил(а)  Пассивное курение  \
# 305                                  True               True
# 654                                 False              False
# 808                                 False              False
#
#      Алкоголь - никогда не употреблял  Алкоголь - ранее употреблял  \
# 305                             False                        False
# 654                             False                        False
# 808                             False                        False
#
#      Алкоголь - употребляю в настоящее время  Сон после обеда  Спорт клубы  \
# 305                                     True             True        False
# 654                                     True             True        False
# 808                                     True             True        False
#
#      Религия клубы
# 305          False
# 654          False
# 808          False

# %% [markdown]
# Также добавим численные фичи

# %%
features['Возраст курения'] = train['Возраст курения']
features['Сигарет в день'] = train['Сигарет в день']
features['Возраст алког'] = train['Возраст алког']
features['Образование - Уровень'] = train['Образование'].str[0].astype(int)

# %%
features.sample(3)
# Out:
#                 ID  Артериальная гипертензия   ОНМК  \
# 851  54-102-094-02                     False  False
# 709  54-002-110-02                     False  False
# 234  54-102-156-02                     False  False
#
#      Стенокардия, ИБС, инфаркт миокарда  Сердечная недостаточность  \
# 851                                True                      False
# 709                               False                      False
# 234                               False                      False
#
#      Прочие заболевания сердца  Пол - М  Семья - в браке в настоящее время  \
# 851                      False     True                               True
# 709                      False     True                               True
# 234                      False     True                               True
#
#      Семья - в разводе  Семья - вдовец / вдова  \
# 851              False                   False
# 709              False                   False
# 234              False                   False
#
#      Семья - гражданский брак / проживание с партнером  \
# 851                                              False
# 709                                              False
# 234                                              False
#
#      Семья - никогда не был(а) в браке  \
# 851                              False
# 709                              False
# 234                              False
#
#      Семья - раздельное проживание (официально не разведены)  \
# 851                                              False
# 709                                              False
# 234                                              False
#
#      Семья - живет один  Этнос - европейская  Этнос - другая азиатская  \
# 851               False                 True                     False
# 709               False                 True                     False
# 234               False                 True                     False
#
#      Этнос - прочее  Национальность - Азербайджанцы  Национальность - Армяне  \
# 851           False                           False                    False
# 709           False                           False                    False
# 234           False                           False                    False
#
#      Национальность - Башкиры  Национальность - Белорусы  \
# 851                     False                      False
# 709                     False                      False
# 234                     False                      False
#
#      Национальность - Буряты  Национальность - Другие национальности  \
# 851                    False                                   False
# 709                    False                                   False
# 234                    False                                   False
#
#      Национальность - Евреи  Национальность - Казахи  \
# 851                   False                    False
# 709                   False                    False
# 234                   False                    False
#
#      Национальность - Киргизы  Национальность - Лезгины  \
# 851                     False                     False
# 709                     False                     False
# 234                     False                     False
#
#      Национальность - Молдаване  Национальность - Мордва  \
# 851                       False                    False
# 709                       False                    False
# 234                       False                    False
#
#      Национальность - Немцы  Национальность - Русские  \
# 851                   False                      True
# 709                   False                      True
# 234                   False                      True
#
#      Национальность - Таджики  Национальность - Татары  \
# 851                     False                    False
# 709                     False                    False
# 234                     False                    False
#
#      Национальность - Удмурты  Национальность - Украинцы  \
# 851                     False                      False
# 709                     False                      False
# 234                     False                      False
#
#      Национальность - Чуваши  Национальность - Эстонцы  \
# 851                    False                     False
# 709                    False                     False
# 234                    False                     False
#
#      Национальность - Азия / Кавказ  \
# 851                           False
# 709                           False
# 234                           False
#
#      Национальность - Русские / Белорусы / Украинцы  \
# 851                                            True
# 709                                            True
# 234                                            True
#
#      Религия - Атеист / агностик  Религия - Другое  Религия - Индуизм  \
# 851                        False             False              False
# 709                        False             False              False
# 234                        False             False              False
#
#      Религия - Ислам  Религия - Нет  Религия - Христианство  \
# 851            False          False                    True
# 709            False          False                    True
# 234            False          False                    True
#
#      Религия - Индуизм / Ислам / Другое  Религия - Верующий  \
# 851                               False                True
# 709                               False                True
# 234                               False                True
#
#      Образование - начальная школа  Образование - среднее  \
# 851                          False                  False
# 709                          False                  False
# 234                          False                  False
#
#      Образование - профессиональное училище  Образование - ВУЗ  \
# 851                                   False               True
# 709                                   False               True
# 234                                   False               True
#
#      Профессия - ведение домашнего хозяйства  Профессия - вооруженные силы  \
# 851                                    False                         False
# 709                                    False                         False
# 234                                    False                         False
#
#      Профессия - дипломированные специалисты  \
# 851                                     True
# 709                                     True
# 234                                    False
#
#      Профессия - квалифицированные работники сельского хозяйства и рыболовного  \
# 851                                              False
# 709                                              False
# 234                                              False
#
#      Профессия - низкоквалифицированные работники  \
# 851                                         False
# 709                                         False
# 234                                         False
#
#      Профессия - операторы и монтажники установок и машинного оборудования  \
# 851                                              False
# 709                                              False
# 234                                              False
#
#      Профессия - законотворцы / менеджеры  Профессия - сфера обслуживания  \
# 851                                 False                           False
# 709                                 False                           False
# 234                                 False                            True
#
#      Профессия - ремесленники и представители других отраслей промышленности  \
# 851                                              False
# 709                                              False
# 234                                              False
#
#      Профессия - служащие  Профессия - техники и младшие специалисты  \
# 851                 False                                      False
# 709                 False                                      False
# 234                 False                                      False
#
#      Профессия - военные / служащие / управление  Профессия - промышленность  \
# 851                                        False                       False
# 709                                        False                       False
# 234                                        False                       False
#
#      Профессия - низкая квалификация  Вы работаете?  Выход на пенсию  \
# 851                            False           True            False
# 709                            False          False             True
# 234                            False           True            False
#
#      Прекращение работы по болезни  Сахарный диабет  Гепатит  Онкология  \
# 851                          False            False    False      False
# 709                          False            False    False      False
# 234                          False            False    False      False
#
#      Хроническое заболевание легких  Бронхиальная астма  Туберкулез легких  \
# 851                           False               False              False
# 709                           False               False              False
# 234                           False               False              False
#
#      ВИЧ/СПИД  Регулярный прием лекарственных средств  Травмы за год  \
# 851     False                                   False          False
# 709     False                                    True          False
# 234     False                                   False           True
#
#      Переломы  Статус Курения - Бросил(а)  Статус Курения - Курит  \
# 851     False                       False                    True
# 709     False                       False                   False
# 234      True                       False                   False
#
#      Статус Курения - Никогда не курил(а)  Пассивное курение  \
# 851                                 False              False
# 709                                  True              False
# 234                                  True               True
#
#      Алкоголь - никогда не употреблял  Алкоголь - ранее употреблял  \
# 851                             False                        False
# 709                             False                        False
# 234                             False                        False
#
#      Алкоголь - употребляю в настоящее время  Сон после обеда  Спорт клубы  \
# 851                                     True            False        False
# 709                                     True            False        False
# 234                                     True            False         True
#
#      Религия клубы  Возраст курения  Сигарет в день  Возраст алког  \
# 851          False             19.0            20.0           20.0
# 709          False              0.0             0.0           25.0
# 234          False              0.0             0.0           17.0
#
#      Образование - Уровень
# 851                      5
# 709                      5
# 234                      5

# %% [markdown]
# Создадим свои фичи

# %%
features['Одинокий мужчина'] = features['Пол - М'] & features['Семья - живет один']
features['Одинокая женщина'] = (~features['Пол - М']) & features['Семья - живет один']

# %%
features['Без работы и не на пенсии'] = (~features['Вы работаете?']) & (~features['Выход на пенсию'])

# %%
features['Сигарет в день (сейчас)'] = features['Сигарет в день']
features.loc[features['Статус Курения - Бросил(а)'], 'Сигарет в день (сейчас)'] = 0

# %% [markdown]
# Посчитаем сколько раз в неделю человек пассивно курит

# %%
def second_hand_smoke_count(value):
    if value == '1-2 раза в неделю':
        return 1.5
    if value == '2-3 раза в день':
        return 17.5
    if value == '3-6 раз в неделю':
        return 4.5
    if value == '4 и более раз в день':
        return 28.0
    if value == 'не менее 1 раза в день':
        return 7.0
    return 0.0

# %%
features['Частота пасс кур'] = train['Частота пасс кур'].apply(second_hand_smoke_count)

# %% [markdown]
# Все что связано со здоровьем

# %%
features['Болезнь легких'] = features['Хроническое заболевание легких'] | features['Бронхиальная астма'] | features['Туберкулез легких']
features['Инфекционная болезнь'] = features['Гепатит'] | features['ВИЧ/СПИД']
features['Хроническая болезнь'] = features['Болезнь легких'] | features['Инфекционная болезнь'] | features['Сахарный диабет'] | features['Онкология']
features['Регулярный прием лекарственных средств без болезней из опроса'] = (features['Хроническая болезнь'] == False) & features['Регулярный прием лекарственных средств']
features['Больной'] = features['Хроническая болезнь'] | features['Прекращение работы по болезни'] | features['Регулярный прием лекарственных средств']
features['Травмы / переломы'] = features['Травмы за год'] | features['Переломы']
features['Идеальное здоровье'] = (features['Больной'] == False) & (features['Травмы / переломы'] == False)
features['Без вредных привычек'] = features['Статус Курения - Никогда не курил(а)'] & features['Алкоголь - никогда не употреблял']
features['Бросил вредную привычку'] = features['Статус Курения - Бросил(а)'] | features['Алкоголь - ранее употреблял']
features['Макс. возраст вредной привычки'] = features[['Возраст курения', 'Возраст алког']].max(axis=1)
features['Само совершенство'] = features['Идеальное здоровье'] & features['Без вредных привычек'] & (features['Пассивное курение'] == False)
features['Активное или пассивное курение'] = features['Пассивное курение'] | features['Статус Курения - Курит']

# %% [markdown]
# Данные по сну

# %%
def round_time(hour, min):
    if min <= 15:
        return hour, 0
    if 15 < min < 45:
        return hour, 30
    return hour + 1, 0

def sleep_time(value):
    hour, min, sec = map(int, value.split(':'))
    hour, min = round_time(hour, min)

    if hour >= 23:
        return (hour - 23) + min / 60
    if hour < 12:
        return hour + 1 + min / 60
    return (hour + min / 60) - 23

def wakeup_time(value):
    hour, min, sec = map(int, value.split(':'))
    hour, min = round_time(hour, min)

    if hour >= 7:
        return (hour - 7) + min / 60
    return (hour + min / 60) - 7

# %%
features['Продолжительность сна'] = 8 + train['Время пробуждения'].apply(wakeup_time) \
                                   - train['Время засыпания'].apply(sleep_time)

# %%
features
# Out:
#                 ID  Артериальная гипертензия   ОНМК  \
# 0    54-102-358-02                     False  False
# 1    54-103-101-01                      True   True
# 2    54-501-026-03                     False  False
# 3    54-501-094-02                      True  False
# 4    54-503-022-01                      True  False
# ..             ...                       ...    ...
# 950  54-103-006-01                     False  False
# 951  54-701-039-01                     False  False
# 952  54-002-014-01                      True  False
# 953  54-501-022-01                     False  False
# 954  54-702-016-01                     False  False
#
#      Стенокардия, ИБС, инфаркт миокарда  Сердечная недостаточность  \
# 0                                 False                      False
# 1                                 False                      False
# 2                                 False                      False
# 3                                 False                      False
# 4                                  True                       True
# ..                                  ...                        ...
# 950                               False                      False
# 951                               False                      False
# 952                                True                      False
# 953                               False                      False
# 954                               False                      False
#
#      Прочие заболевания сердца  Пол - М  Семья - в браке в настоящее время  \
# 0                        False     True                               True
# 1                        False    False                              False
# 2                        False    False                               True
# 3                        False     True                               True
# 4                        False    False                               True
# ..                         ...      ...                                ...
# 950                      False     True                               True
# 951                      False    False                              False
# 952                      False    False                               True
# 953                      False    False                               True
# 954                      False     True                               True
#
#      Семья - в разводе  Семья - вдовец / вдова  \
# 0                False                   False
# 1                 True                   False
# 2                False                   False
# 3                False                   False
# 4                False                   False
# ..                 ...                     ...
# 950              False                   False
# 951              False                    True
# 952              False                   False
# 953              False                   False
# 954              False                   False
#
#      Семья - гражданский брак / проживание с партнером  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 950                                              False
# 951                                              False
# 952                                              False
# 953                                              False
# 954                                              False
#
#      Семья - никогда не был(а) в браке  \
# 0                                False
# 1                                False
# 2                                False
# 3                                False
# 4                                False
# ..                                 ...
# 950                              False
# 951                              False
# 952                              False
# 953                              False
# 954                              False
#
#      Семья - раздельное проживание (официально не разведены)  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 950                                              False
# 951                                              False
# 952                                              False
# 953                                              False
# 954                                              False
#
#      Семья - живет один  Этнос - европейская  Этнос - другая азиатская  \
# 0                 False                 True                     False
# 1                  True                 True                     False
# 2                 False                 True                     False
# 3                 False                 True                     False
# 4                 False                 True                     False
# ..                  ...                  ...                       ...
# 950               False                 True                     False
# 951                True                 True                     False
# 952               False                 True                     False
# 953               False                 True                     False
# 954               False                 True                     False
#
#      Этнос - прочее  Национальность - Азербайджанцы  Национальность - Армяне  \
# 0             False                           False                    False
# 1             False                           False                    False
# 2             False                           False                    False
# 3             False                           False                    False
# 4             False                           False                    False
# ..              ...                             ...                      ...
# 950           False                           False                    False
# 951           False                           False                    False
# 952           False                           False                    False
# 953           False                           False                    False
# 954           False                           False                    False
#
#      Национальность - Башкиры  Национальность - Белорусы  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# ..                        ...                        ...
# 950                     False                      False
# 951                     False                      False
# 952                     False                      False
# 953                     False                      False
# 954                     False                      False
#
#      Национальность - Буряты  Национальность - Другие национальности  \
# 0                      False                                   False
# 1                      False                                   False
# 2                      False                                   False
# 3                      False                                   False
# 4                      False                                   False
# ..                       ...                                     ...
# 950                    False                                   False
# 951                    False                                   False
# 952                    False                                   False
# 953                    False                                   False
# 954                    False                                   False
#
#      Национальность - Евреи  Национальность - Казахи  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
# ..                      ...                      ...
# 950                   False                    False
# 951                   False                    False
# 952                   False                    False
# 953                   False                    False
# 954                   False                    False
#
#      Национальность - Киргизы  Национальность - Лезгины  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
# ..                        ...                       ...
# 950                     False                     False
# 951                     False                     False
# 952                     False                     False
# 953                     False                     False
# 954                     False                     False
#
#      Национальность - Молдаване  Национальность - Мордва  \
# 0                         False                    False
# 1                         False                    False
# 2                         False                    False
# 3                         False                    False
# 4                         False                    False
# ..                          ...                      ...
# 950                       False                    False
# 951                       False                    False
# 952                       False                    False
# 953                       False                    False
# 954                       False                    False
#
#      Национальность - Немцы  Национальность - Русские  \
# 0                     False                      True
# 1                     False                      True
# 2                     False                      True
# 3                     False                      True
# 4                     False                      True
# ..                      ...                       ...
# 950                   False                      True
# 951                   False                      True
# 952                   False                      True
# 953                   False                      True
# 954                   False                      True
#
#      Национальность - Таджики  Национальность - Татары  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ..                        ...                      ...
# 950                     False                    False
# 951                     False                    False
# 952                     False                    False
# 953                     False                    False
# 954                     False                    False
#
#      Национальность - Удмурты  Национальность - Украинцы  \
# 0                       False                      False
# 1                       False                      False
# 2                       False                      False
# 3                       False                      False
# 4                       False                      False
# ..                        ...                        ...
# 950                     False                      False
# 951                     False                      False
# 952                     False                      False
# 953                     False                      False
# 954                     False                      False
#
#      Национальность - Чуваши  Национальность - Эстонцы  \
# 0                      False                     False
# 1                      False                     False
# 2                      False                     False
# 3                      False                     False
# 4                      False                     False
# ..                       ...                       ...
# 950                    False                     False
# 951                    False                     False
# 952                    False                     False
# 953                    False                     False
# 954                    False                     False
#
#      Национальность - Азия / Кавказ  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
# ..                              ...
# 950                           False
# 951                           False
# 952                           False
# 953                           False
# 954                           False
#
#      Национальность - Русские / Белорусы / Украинцы  \
# 0                                              True
# 1                                              True
# 2                                              True
# 3                                              True
# 4                                              True
# ..                                              ...
# 950                                            True
# 951                                            True
# 952                                            True
# 953                                            True
# 954                                            True
#
#      Религия - Атеист / агностик  Религия - Другое  Религия - Индуизм  \
# 0                          False             False              False
# 1                          False             False              False
# 2                          False             False              False
# 3                           True             False              False
# 4                          False             False              False
# ..                           ...               ...                ...
# 950                        False             False              False
# 951                        False             False              False
# 952                        False             False              False
# 953                         True             False              False
# 954                        False             False              False
#
#      Религия - Ислам  Религия - Нет  Религия - Христианство  \
# 0              False          False                    True
# 1              False          False                    True
# 2              False          False                    True
# 3              False          False                   False
# 4              False          False                    True
# ..               ...            ...                     ...
# 950            False          False                    True
# 951            False          False                    True
# 952            False          False                    True
# 953            False          False                   False
# 954            False          False                    True
#
#      Религия - Индуизм / Ислам / Другое  Религия - Верующий  \
# 0                                 False                True
# 1                                 False                True
# 2                                 False                True
# 3                                 False               False
# 4                                 False                True
# ..                                  ...                 ...
# 950                               False                True
# 951                               False                True
# 952                               False                True
# 953                               False               False
# 954                               False                True
#
#      Образование - начальная школа  Образование - среднее  \
# 0                            False                   True
# 1                            False                  False
# 2                            False                  False
# 3                            False                   True
# 4                            False                   True
# ..                             ...                    ...
# 950                          False                  False
# 951                          False                   True
# 952                          False                   True
# 953                          False                  False
# 954                          False                  False
#
#      Образование - профессиональное училище  Образование - ВУЗ  \
# 0                                     False              False
# 1                                     False               True
# 2                                     False               True
# 3                                     False              False
# 4                                     False              False
# ..                                      ...                ...
# 950                                    True              False
# 951                                   False              False
# 952                                   False              False
# 953                                   False               True
# 954                                    True              False
#
#      Профессия - ведение домашнего хозяйства  Профессия - вооруженные силы  \
# 0                                      False                         False
# 1                                      False                         False
# 2                                      False                         False
# 3                                      False                         False
# 4                                      False                         False
# ..                                       ...                           ...
# 950                                    False                         False
# 951                                    False                         False
# 952                                    False                         False
# 953                                    False                         False
# 954                                    False                         False
#
#      Профессия - дипломированные специалисты  \
# 0                                      False
# 1                                       True
# 2                                       True
# 3                                      False
# 4                                      False
# ..                                       ...
# 950                                    False
# 951                                    False
# 952                                    False
# 953                                    False
# 954                                    False
#
#      Профессия - квалифицированные работники сельского хозяйства и рыболовного  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 950                                              False
# 951                                              False
# 952                                              False
# 953                                              False
# 954                                              False
#
#      Профессия - низкоквалифицированные работники  \
# 0                                            True
# 1                                           False
# 2                                           False
# 3                                            True
# 4                                           False
# ..                                            ...
# 950                                         False
# 951                                          True
# 952                                         False
# 953                                         False
# 954                                         False
#
#      Профессия - операторы и монтажники установок и машинного оборудования  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                 True
# ..                                                 ...
# 950                                               True
# 951                                              False
# 952                                              False
# 953                                              False
# 954                                               True
#
#      Профессия - законотворцы / менеджеры  Профессия - сфера обслуживания  \
# 0                                   False                           False
# 1                                   False                           False
# 2                                   False                           False
# 3                                   False                           False
# 4                                   False                           False
# ..                                    ...                             ...
# 950                                 False                           False
# 951                                 False                           False
# 952                                 False                           False
# 953                                  True                           False
# 954                                 False                           False
#
#      Профессия - ремесленники и представители других отраслей промышленности  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ..                                                 ...
# 950                                              False
# 951                                              False
# 952                                              False
# 953                                              False
# 954                                              False
#
#      Профессия - служащие  Профессия - техники и младшие специалисты  \
# 0                   False                                      False
# 1                   False                                      False
# 2                   False                                      False
# 3                   False                                      False
# 4                   False                                      False
# ..                    ...                                        ...
# 950                 False                                      False
# 951                 False                                      False
# 952                  True                                      False
# 953                 False                                      False
# 954                 False                                      False
#
#      Профессия - военные / служащие / управление  Профессия - промышленность  \
# 0                                          False                       False
# 1                                          False                       False
# 2                                          False                       False
# 3                                          False                       False
# 4                                          False                        True
# ..                                           ...                         ...
# 950                                        False                        True
# 951                                        False                       False
# 952                                         True                       False
# 953                                         True                       False
# 954                                        False                        True
#
#      Профессия - низкая квалификация  Вы работаете?  Выход на пенсию  \
# 0                               True           True            False
# 1                              False          False            False
# 2                              False          False            False
# 3                               True           True            False
# 4                              False          False            False
# ..                               ...            ...              ...
# 950                            False           True            False
# 951                             True           True            False
# 952                            False          False             True
# 953                            False           True            False
# 954                            False           True            False
#
#      Прекращение работы по болезни  Сахарный диабет  Гепатит  Онкология  \
# 0                            False            False    False      False
# 1                            False             True    False      False
# 2                            False            False    False      False
# 3                            False            False    False       True
# 4                             True             True     True      False
# ..                             ...              ...      ...        ...
# 950                          False            False    False      False
# 951                          False            False    False      False
# 952                          False            False    False      False
# 953                          False            False     True      False
# 954                          False            False    False      False
#
#      Хроническое заболевание легких  Бронхиальная астма  Туберкулез легких  \
# 0                             False               False              False
# 1                             False               False              False
# 2                             False               False              False
# 3                             False               False              False
# 4                             False               False              False
# ..                              ...                 ...                ...
# 950                           False               False              False
# 951                           False               False              False
# 952                           False               False              False
# 953                           False               False              False
# 954                           False               False              False
#
#      ВИЧ/СПИД  Регулярный прием лекарственных средств  Травмы за год  \
# 0       False                                   False          False
# 1       False                                    True          False
# 2       False                                    True          False
# 3       False                                    True          False
# 4       False                                    True          False
# ..        ...                                     ...            ...
# 950     False                                   False          False
# 951     False                                    True          False
# 952     False                                    True          False
# 953     False                                    True          False
# 954     False                                   False          False
#
#      Переломы  Статус Курения - Бросил(а)  Статус Курения - Курит  \
# 0       False                       False                    True
# 1        True                       False                   False
# 2       False                       False                   False
# 3       False                        True                   False
# 4        True                       False                   False
# ..        ...                         ...                     ...
# 950      True                       False                    True
# 951     False                       False                    True
# 952     False                        True                   False
# 953     False                       False                   False
# 954      True                       False                    True
#
#      Статус Курения - Никогда не курил(а)  Пассивное курение  \
# 0                                   False              False
# 1                                    True              False
# 2                                    True               True
# 3                                   False               True
# 4                                    True               True
# ..                                    ...                ...
# 950                                 False              False
# 951                                 False              False
# 952                                 False              False
# 953                                  True              False
# 954                                 False              False
#
#      Алкоголь - никогда не употреблял  Алкоголь - ранее употреблял  \
# 0                               False                        False
# 1                                True                        False
# 2                               False                        False
# 3                               False                        False
# 4                               False                        False
# ..                                ...                          ...
# 950                             False                        False
# 951                             False                         True
# 952                             False                        False
# 953                             False                        False
# 954                             False                        False
#
#      Алкоголь - употребляю в настоящее время  Сон после обеда  Спорт клубы  \
# 0                                       True            False        False
# 1                                      False             True        False
# 2                                       True            False        False
# 3                                       True            False        False
# 4                                       True            False        False
# ..                                       ...              ...          ...
# 950                                     True            False        False
# 951                                    False            False        False
# 952                                     True             True        False
# 953                                     True            False         True
# 954                                     True             True        False
#
#      Религия клубы  Возраст курения  Сигарет в день  Возраст алког  \
# 0            False             15.0            20.0           18.0
# 1            False              0.0             0.0            0.0
# 2            False              0.0             0.0           17.0
# 3            False             12.0            10.0           13.0
# 4            False              0.0             0.0           16.0
# ..             ...              ...             ...            ...
# 950          False             16.0            20.0           18.0
# 951          False             15.0            10.0           26.0
# 952          False             20.0            10.0           20.0
# 953          False              0.0             0.0           21.0
# 954          False             10.0            30.0           17.0
#
#      Образование - Уровень  Одинокий мужчина  Одинокая женщина  \
# 0                        3             False             False
# 1                        5             False              True
# 2                        5             False             False
# 3                        3             False             False
# 4                        3             False             False
# ..                     ...               ...               ...
# 950                      4             False             False
# 951                      3             False              True
# 952                      3             False             False
# 953                      5             False             False
# 954                      4             False             False
#
#      Без работы и не на пенсии  Сигарет в день (сейчас)  Частота пасс кур  \
# 0                        False                     20.0               0.0
# 1                         True                      0.0               0.0
# 2                         True                      0.0               1.5
# 3                        False                      0.0               4.5
# 4                         True                      0.0               7.0
# ..                         ...                      ...               ...
# 950                      False                     20.0               0.0
# 951                      False                     10.0               0.0
# 952                      False                      0.0               0.0
# 953                      False                      0.0               0.0
# 954                      False                     30.0               0.0
#
#      Болезнь легких  Инфекционная болезнь  Хроническая болезнь  \
# 0             False                 False                False
# 1             False                 False                 True
# 2             False                 False                False
# 3             False                 False                 True
# 4             False                  True                 True
# ..              ...                   ...                  ...
# 950           False                 False                False
# 951           False                 False                False
# 952           False                 False                False
# 953           False                  True                 True
# 954           False                 False                False
#
#      Регулярный прием лекарственных средств без болезней из опроса  Больной  \
# 0                                                False                False
# 1                                                False                 True
# 2                                                 True                 True
# 3                                                False                 True
# 4                                                False                 True
# ..                                                 ...                  ...
# 950                                              False                False
# 951                                               True                 True
# 952                                               True                 True
# 953                                              False                 True
# 954                                              False                False
#
#      Травмы / переломы  Идеальное здоровье  Без вредных привычек  \
# 0                False                True                 False
# 1                 True               False                  True
# 2                False               False                 False
# 3                False               False                 False
# 4                 True               False                 False
# ..                 ...                 ...                   ...
# 950               True               False                 False
# 951              False               False                 False
# 952              False               False                 False
# 953              False               False                 False
# 954               True               False                 False
#
#      Бросил вредную привычку  Макс. возраст вредной привычки  \
# 0                      False                            18.0
# 1                      False                             0.0
# 2                      False                            17.0
# 3                       True                            13.0
# 4                      False                            16.0
# ..                       ...                             ...
# 950                    False                            18.0
# 951                     True                            26.0
# 952                     True                            20.0
# 953                    False                            21.0
# 954                    False                            17.0
#
#      Само совершенство  Активное или пассивное курение  Продолжительность сна
# 0                False                            True                    8.0
# 1                False                           False                    4.0
# 2                False                            True                    8.0
# 3                False                            True                    8.0
# 4                False                            True                    7.0
# ..                 ...                             ...                    ...
# 950              False                            True                    8.0
# 951              False                            True                    9.5
# 952              False                           False                    9.5
# 953              False                           False                    9.5
# 954              False                            True                    7.0
#
# [955 rows x 110 columns]

# %% [markdown]
# ## Объединим все в одну функцию

# %% [markdown]
# ### Глобальные переменные

# %%
TARGETS = [
    'Артериальная гипертензия',
    'ОНМК',
    'Стенокардия, ИБС, инфаркт миокарда',
    'Сердечная недостаточность',
    'Прочие заболевания сердца',
]

# %%
base_features = [
    ('Пол - М', 'Пол', ['М']),
    ('Семья - в браке в настоящее время', 'Семья', ['в браке в настоящее время']),
    ('Семья - в разводе', 'Семья', ['в разводе']),
    ('Семья - вдовец / вдова', 'Семья', ['вдовец / вдова']),
    ('Семья - гражданский брак / проживание с партнером', 'Семья', ['гражданский брак / проживание с партнером']),
    ('Семья - никогда не был(а) в браке', 'Семья', ['никогда не был(а) в браке']),
    ('Семья - раздельное проживание (официально не разведены)', 'Семья', ['раздельное проживание (официально не разведены)']),
    ('Семья - живет один', 'Семья', ['в разводе', 'вдовец / вдова', 'никогда не был(а) в браке', 'раздельное проживание (официально не разведены)']),
    ('Этнос - европейская', 'Этнос', ['европейская']),
    ('Этнос - другая азиатская', 'Этнос', ['другая азиатская (Корея, Малайзия, Таиланд, Вьетнам, Казахстан, Киргизия, Туркмения, Узбекистан, Таджикистан)']),
    ('Этнос - прочее', 'Этнос', ['прочее (любая иная этно-расовая группа, не представленная выше)']),
    ('Национальность - Азербайджанцы', 'Национальность', ['Азербайджанцы']),
    ('Национальность - Армяне', 'Национальность', ['Армяне']),
    ('Национальность - Башкиры', 'Национальность', ['Башкиры']),
    ('Национальность - Белорусы', 'Национальность', ['Белорусы']),
    ('Национальность - Буряты', 'Национальность', ['Буряты']),
    ('Национальность - Другие национальности', 'Национальность', ['Другие национальности']),
    ('Национальность - Евреи', 'Национальность', ['Евреи']),
    ('Национальность - Казахи', 'Национальность', ['Казахи']),
    ('Национальность - Киргизы', 'Национальность', ['Киргизы']),
    ('Национальность - Лезгины', 'Национальность', ['Лезгины']),
    ('Национальность - Молдаване', 'Национальность', ['Молдаване']),
    ('Национальность - Мордва', 'Национальность', ['Мордва']),
    ('Национальность - Немцы', 'Национальность', ['Немцы']),
    ('Национальность - Русские', 'Национальность', ['Русские']),
    ('Национальность - Таджики', 'Национальность', ['Таджики']),
    ('Национальность - Татары', 'Национальность', ['Татары']),
    ('Национальность - Удмурты', 'Национальность', ['Удмурты']),
    ('Национальность - Украинцы', 'Национальность', ['Украинцы']),
    ('Национальность - Чуваши', 'Национальность', ['Чуваши']),
    ('Национальность - Эстонцы', 'Национальность', ['Эстонцы']),
    ('Национальность - Азия / Кавказ', 'Национальность', ['Азербайджанцы', 'Армяне', 'Казахи', 'Киргизы', 'Лезгины', 'Таджики']),
    ('Национальность - Русские / Белорусы / Украинцы', 'Национальность', ['Русские', 'Белорусы', 'Украинцы']),
    ('Религия - Атеист / агностик', 'Религия', ['Атеист / агностик']),
    ('Религия - Другое', 'Религия', ['Другое']),
    ('Религия - Индуизм', 'Религия', ['Индуизм']),
    ('Религия - Ислам', 'Религия', ['Ислам']),
    ('Религия - Нет', 'Религия', ['Нет']),
    ('Религия - Христианство', 'Религия', ['Христианство']),
    ('Религия - Индуизм / Ислам / Другое', 'Религия', ['Индуизм', 'Ислам', 'Другое']),
    ('Религия - Верующий', 'Религия', ['Другое', 'Индуизм', 'Ислам', 'Христианство']),
    ('Образование - начальная школа', 'Образование', ['2 - начальная школа']),
    ('Образование - среднее', 'Образование', ['3 - средняя школа / закон.среднее / выше среднего']),
    ('Образование - профессиональное училище', 'Образование', ['4 - профессиональное училище']),
    ('Образование - ВУЗ', 'Образование', ['5 - ВУЗ']),
    ('Профессия - ведение домашнего хозяйства', 'Профессия', ['ведение домашнего хозяйства']),
    ('Профессия - вооруженные силы', 'Профессия', ['вооруженные силы']),
    ('Профессия - дипломированные специалисты', 'Профессия', ['дипломированные специалисты']),
    ('Профессия - квалифицированные работники сельского хозяйства и рыболовного', 'Профессия', ['квалифицированные работники сельского хозяйства и рыболовного']),
    ('Профессия - низкоквалифицированные работники', 'Профессия', ['низкоквалифицированные работники']),
    ('Профессия - операторы и монтажники установок и машинного оборудования', 'Профессия', ['операторы и монтажники установок и машинного оборудования']),
    ('Профессия - законотворцы / менеджеры', 'Профессия', ['представители   законодат.   органов   власти,  высокопостав. долж.лица и менеджеры']),
    ('Профессия - сфера обслуживания', 'Профессия', ['работники,  занятые в сфере обслуживания, торговые работники магазинов и рынков']),
    ('Профессия - ремесленники и представители других отраслей промышленности', 'Профессия', ['ремесленники и представители других отраслей промышленности']),
    ('Профессия - служащие', 'Профессия', ['служащие']),
    ('Профессия - техники и младшие специалисты', 'Профессия', ['техники и младшие специалисты']),
    ('Профессия - военные / служащие / управление', 'Профессия', ['вооруженные силы', 'представители   законодат.   органов   власти,  высокопостав. долж.лица и менеджеры', 'служащие']),
    ('Профессия - промышленность', 'Профессия', ['операторы и монтажники установок и машинного оборудования', 'ремесленники и представители других отраслей промышленности', 'техники и младшие специалисты']),
    ('Профессия - низкая квалификация', 'Профессия', ['низкоквалифицированные работники', 'ведение домашнего хозяйства']),
    ('Вы работаете?', 'Вы работаете?', [1]),
    ('Выход на пенсию', 'Выход на пенсию', [1]),
    ('Прекращение работы по болезни', 'Прекращение работы по болезни', [1]),
    ('Сахарный диабет', 'Сахарный диабет', [1]),
    ('Гепатит', 'Гепатит', [1]),
    ('Онкология', 'Онкология', [1]),
    ('Хроническое заболевание легких', 'Хроническое заболевание легких', [1]),
    ('Бронхиальная астма', 'Бронжиальная астма', [1]),
    ('Туберкулез легких', 'Туберкулез легких ', [1]),
    ('ВИЧ/СПИД', 'ВИЧ/СПИД', [1]),
    ('Регулярный прием лекарственных средств', 'Регулярный прим лекарственных средств', [1]),
    ('Травмы за год', 'Травмы за год', [1]),
    ('Переломы', 'Переломы', [1]),
    ('Статус Курения - Бросил(а)', 'Статус Курения', ['Бросил(а)']),
    ('Статус Курения - Курит', 'Статус Курения', ['Курит']),
    ('Статус Курения - Никогда не курил(а)', 'Статус Курения', ['Никогда не курил(а)']),
    ('Пассивное курение', 'Пассивное курение', [1]),
    ('Алкоголь - никогда не употреблял', 'Алкоголь', ['никогда не употреблял']),
    ('Алкоголь - ранее употреблял', 'Алкоголь', ['ранее употреблял']),
    ('Алкоголь - употребляю в настоящее время', 'Алкоголь', ['употребляю в настоящее время']),
    ('Сон после обеда', 'Сон после обеда', [1]),
    ('Спорт клубы', 'Спорт, клубы', [1]),
    ('Религия клубы', 'Религия, клубы', [1]),
]

# %% [markdown]
# ### Функции

# %%
def second_hand_smoke_count(value):
    if value == '1-2 раза в неделю':
        return 1.5
    if value == '2-3 раза в день':
        return 17.5
    if value == '3-6 раз в неделю':
        return 4.5
    if value == '4 и более раз в день':
        return 28.0
    if value == 'не менее 1 раза в день':
        return 7.0
    return 0.0

def round_time(hour, min):
    if min <= 15:
        return hour, 0
    if 15 < min < 45:
        return hour, 30
    return hour + 1, 0

def sleep_time(value):
    hour, min, sec = map(int, value.split(':'))
    hour, min = round_time(hour, min)

    if hour >= 23:
        return (hour - 23) + min / 60
    if hour < 12:
        return hour + 1 + min / 60
    return (hour + min / 60) - 23

def wakeup_time(value):
    hour, min, sec = map(int, value.split(':'))
    hour, min = round_time(hour, min)

    if hour >= 7:
        return (hour - 7) + min / 60
    return (hour + min / 60) - 7

# %% [markdown]
# ### Итоговая функция

# %%
def create_features(data : pd.DataFrame, is_train : bool) -> pd.DataFrame:
    
    if is_train:
        data['Пол'].fillna('Ж', inplace=True)  # 54-701-009-01
        data['Время засыпания'].replace('12:00:00', '00:00:00', inplace=True)  # 54-002-054-02
        data.loc[train['Частота пасс кур'].isna() == False, 'Пассивное курение'] = 1  # 54-001-079-01
    
    else:
        data['Статус Курения'].replace('Никогда не курил', 'Никогда не курил(а)', inplace=True)  # 54-701-037-01
        data['Время засыпания'].replace('09:00:00', '21:00:00', inplace=True)  # 54-602-001-01
        data['Время засыпания'].replace('00:00:30', '00:30:00', inplace=True)  # 54-103-014-01
        data['Время пробуждения'].replace('00:06:00', '06:00:00', inplace=True)
        
    no_time = (data['Время засыпания'] == data['Время пробуждения'])
    data.loc[no_time, ['Время засыпания']] = '23:00:00'
    data.loc[no_time, ['Время пробуждения']] = '07:00:00'
    
    data.fillna(0, inplace=True)
    
    features = data[['ID']].copy()
    
    if is_train:
        for target in TARGETS:
            features[target] = data[target] == 1 
            
    for name, column, values in base_features:
        features[name] = data[column].isin(values)
        
    features['Возраст курения'] = data['Возраст курения']
    features['Сигарет в день'] = data['Сигарет в день']
    features['Возраст алког'] = data['Возраст алког']
    features['Образование - Уровень'] = data['Образование'].str[0].astype(int)
    
    features['Одинокий мужчина'] = features['Пол - М'] & features['Семья - живет один']
    features['Одинокая женщина'] = (~features['Пол - М']) & features['Семья - живет один']

    features['Без работы и не на пенсии'] = (~features['Вы работаете?']) & (~features['Выход на пенсию'])

    features['Сигарет в день (сейчас)'] = features['Сигарет в день']
    features.loc[features['Статус Курения - Бросил(а)'], 'Сигарет в день (сейчас)'] = 0
    
    features['Частота пасс кур'] = train['Частота пасс кур'].apply(second_hand_smoke_count)

    features['Болезнь легких'] = features['Хроническое заболевание легких'] | features['Бронхиальная астма'] | features['Туберкулез легких']
    features['Инфекционная болезнь'] = features['Гепатит'] | features['ВИЧ/СПИД']
    features['Хроническая болезнь'] = features['Болезнь легких'] | features['Инфекционная болезнь'] | features['Сахарный диабет'] | features['Онкология']
    features['Регулярный прием лекарственных средств без болезней из опроса'] = (features['Хроническая болезнь'] == False) & features['Регулярный прием лекарственных средств']
    features['Больной'] = features['Хроническая болезнь'] | features['Прекращение работы по болезни'] | features['Регулярный прием лекарственных средств']
    features['Травмы / переломы'] = features['Травмы за год'] | features['Переломы']
    features['Идеальное здоровье'] = (features['Больной'] == False) & (features['Травмы / переломы'] == False)
    features['Без вредных привычек'] = features['Статус Курения - Никогда не курил(а)'] & features['Алкоголь - никогда не употреблял']
    features['Бросил вредную привычку'] = features['Статус Курения - Бросил(а)'] | features['Алкоголь - ранее употреблял']
    features['Макс. возраст вредной привычки'] = features[['Возраст курения', 'Возраст алког']].max(axis=1)
    features['Само совершенство'] = features['Идеальное здоровье'] & features['Без вредных привычек'] & (features['Пассивное курение'] == False)
    features['Активное или пассивное курение'] = features['Пассивное курение'] | features['Статус Курения - Курит']
    
    features['Продолжительность сна'] = 8 + train['Время пробуждения'].apply(wakeup_time) \
                                   - train['Время засыпания'].apply(sleep_time)
    
    return features

# %% [markdown]
# # Тестируем функцию

# %%
raw_path = '../data/raw/'
train = pd.read_csv(os.path.join(raw_path, 'train.csv'))
test = pd.read_csv(os.path.join(raw_path, 'test.csv'))

# %%
train_features = create_features(train, True)

# %%
train_features.shape
# Out:
# (955, 110)

# %%
train_features.head()
# Out:
#               ID  Артериальная гипертензия   ОНМК  \
# 0  54-102-358-02                     False  False
# 1  54-103-101-01                      True   True
# 2  54-501-026-03                     False  False
# 3  54-501-094-02                      True  False
# 4  54-503-022-01                      True  False
#
#    Стенокардия, ИБС, инфаркт миокарда  Сердечная недостаточность  \
# 0                               False                      False
# 1                               False                      False
# 2                               False                      False
# 3                               False                      False
# 4                                True                       True
#
#    Прочие заболевания сердца  Пол - М  Семья - в браке в настоящее время  \
# 0                      False     True                               True
# 1                      False    False                              False
# 2                      False    False                               True
# 3                      False     True                               True
# 4                      False    False                               True
#
#    Семья - в разводе  Семья - вдовец / вдова  \
# 0              False                   False
# 1               True                   False
# 2              False                   False
# 3              False                   False
# 4              False                   False
#
#    Семья - гражданский брак / проживание с партнером  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Семья - никогда не был(а) в браке  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    Семья - раздельное проживание (официально не разведены)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Семья - живет один  Этнос - европейская  Этнос - другая азиатская  \
# 0               False                 True                     False
# 1                True                 True                     False
# 2               False                 True                     False
# 3               False                 True                     False
# 4               False                 True                     False
#
#    Этнос - прочее  Национальность - Азербайджанцы  Национальность - Армяне  \
# 0           False                           False                    False
# 1           False                           False                    False
# 2           False                           False                    False
# 3           False                           False                    False
# 4           False                           False                    False
#
#    Национальность - Башкиры  Национальность - Белорусы  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    Национальность - Буряты  Национальность - Другие национальности  \
# 0                    False                                   False
# 1                    False                                   False
# 2                    False                                   False
# 3                    False                                   False
# 4                    False                                   False
#
#    Национальность - Евреи  Национальность - Казахи  Национальность - Киргизы  \
# 0                   False                    False                     False
# 1                   False                    False                     False
# 2                   False                    False                     False
# 3                   False                    False                     False
# 4                   False                    False                     False
#
#    Национальность - Лезгины  Национальность - Молдаване  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    Национальность - Мордва  Национальность - Немцы  Национальность - Русские  \
# 0                    False                   False                      True
# 1                    False                   False                      True
# 2                    False                   False                      True
# 3                    False                   False                      True
# 4                    False                   False                      True
#
#    Национальность - Таджики  Национальность - Татары  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
#
#    Национальность - Удмурты  Национальность - Украинцы  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    Национальность - Чуваши  Национальность - Эстонцы  \
# 0                    False                     False
# 1                    False                     False
# 2                    False                     False
# 3                    False                     False
# 4                    False                     False
#
#    Национальность - Азия / Кавказ  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    Национальность - Русские / Белорусы / Украинцы  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
#
#    Религия - Атеист / агностик  Религия - Другое  Религия - Индуизм  \
# 0                        False             False              False
# 1                        False             False              False
# 2                        False             False              False
# 3                         True             False              False
# 4                        False             False              False
#
#    Религия - Ислам  Религия - Нет  Религия - Христианство  \
# 0            False          False                    True
# 1            False          False                    True
# 2            False          False                    True
# 3            False          False                   False
# 4            False          False                    True
#
#    Религия - Индуизм / Ислам / Другое  Религия - Верующий  \
# 0                               False                True
# 1                               False                True
# 2                               False                True
# 3                               False               False
# 4                               False                True
#
#    Образование - начальная школа  Образование - среднее  \
# 0                          False                   True
# 1                          False                  False
# 2                          False                  False
# 3                          False                   True
# 4                          False                   True
#
#    Образование - профессиональное училище  Образование - ВУЗ  \
# 0                                   False              False
# 1                                   False               True
# 2                                   False               True
# 3                                   False              False
# 4                                   False              False
#
#    Профессия - ведение домашнего хозяйства  Профессия - вооруженные силы  \
# 0                                    False                         False
# 1                                    False                         False
# 2                                    False                         False
# 3                                    False                         False
# 4                                    False                         False
#
#    Профессия - дипломированные специалисты  \
# 0                                    False
# 1                                     True
# 2                                     True
# 3                                    False
# 4                                    False
#
#    Профессия - квалифицированные работники сельского хозяйства и рыболовного  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Профессия - низкоквалифицированные работники  \
# 0                                          True
# 1                                         False
# 2                                         False
# 3                                          True
# 4                                         False
#
#    Профессия - операторы и монтажники установок и машинного оборудования  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#    Профессия - законотворцы / менеджеры  Профессия - сфера обслуживания  \
# 0                                 False                           False
# 1                                 False                           False
# 2                                 False                           False
# 3                                 False                           False
# 4                                 False                           False
#
#    Профессия - ремесленники и представители других отраслей промышленности  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Профессия - служащие  Профессия - техники и младшие специалисты  \
# 0                 False                                      False
# 1                 False                                      False
# 2                 False                                      False
# 3                 False                                      False
# 4                 False                                      False
#
#    Профессия - военные / служащие / управление  Профессия - промышленность  \
# 0                                        False                       False
# 1                                        False                       False
# 2                                        False                       False
# 3                                        False                       False
# 4                                        False                        True
#
#    Профессия - низкая квалификация  Вы работаете?  Выход на пенсию  \
# 0                             True           True            False
# 1                            False          False            False
# 2                            False          False            False
# 3                             True           True            False
# 4                            False          False            False
#
#    Прекращение работы по болезни  Сахарный диабет  Гепатит  Онкология  \
# 0                          False            False    False      False
# 1                          False             True    False      False
# 2                          False            False    False      False
# 3                          False            False    False       True
# 4                           True             True     True      False
#
#    Хроническое заболевание легких  Бронхиальная астма  Туберкулез легких  \
# 0                           False               False              False
# 1                           False               False              False
# 2                           False               False              False
# 3                           False               False              False
# 4                           False               False              False
#
#    ВИЧ/СПИД  Регулярный прием лекарственных средств  Травмы за год  Переломы  \
# 0     False                                   False          False     False
# 1     False                                    True          False      True
# 2     False                                    True          False     False
# 3     False                                    True          False     False
# 4     False                                    True          False      True
#
#    Статус Курения - Бросил(а)  Статус Курения - Курит  \
# 0                       False                    True
# 1                       False                   False
# 2                       False                   False
# 3                        True                   False
# 4                       False                   False
#
#    Статус Курения - Никогда не курил(а)  Пассивное курение  \
# 0                                 False               True
# 1                                  True               True
# 2                                  True               True
# 3                                 False               True
# 4                                  True               True
#
#    Алкоголь - никогда не употреблял  Алкоголь - ранее употреблял  \
# 0                             False                        False
# 1                              True                        False
# 2                             False                        False
# 3                             False                        False
# 4                             False                        False
#
#    Алкоголь - употребляю в настоящее время  Сон после обеда  Спорт клубы  \
# 0                                     True            False        False
# 1                                    False             True        False
# 2                                     True            False        False
# 3                                     True            False        False
# 4                                     True            False        False
#
#    Религия клубы  Возраст курения  Сигарет в день  Возраст алког  \
# 0          False             15.0            20.0           18.0
# 1          False              0.0             0.0            0.0
# 2          False              0.0             0.0           17.0
# 3          False             12.0            10.0           13.0
# 4          False              0.0             0.0           16.0
#
#    Образование - Уровень  Одинокий мужчина  Одинокая женщина  \
# 0                      3             False             False
# 1                      5             False              True
# 2                      5             False             False
# 3                      3             False             False
# 4                      3             False             False
#
#    Без работы и не на пенсии  Сигарет в день (сейчас)  Частота пасс кур  \
# 0                      False                     20.0               0.0
# 1                       True                      0.0               0.0
# 2                       True                      0.0               1.5
# 3                      False                      0.0               4.5
# 4                       True                      0.0               7.0
#
#    Болезнь легких  Инфекционная болезнь  Хроническая болезнь  \
# 0           False                 False                False
# 1           False                 False                 True
# 2           False                 False                False
# 3           False                 False                 True
# 4           False                  True                 True
#
#    Регулярный прием лекарственных средств без болезней из опроса  Больной  \
# 0                                              False                False
# 1                                              False                 True
# 2                                               True                 True
# 3                                              False                 True
# 4                                              False                 True
#
#    Травмы / переломы  Идеальное здоровье  Без вредных привычек  \
# 0              False                True                 False
# 1               True               False                  True
# 2              False               False                 False
# 3              False               False                 False
# 4               True               False                 False
#
#    Бросил вредную привычку  Макс. возраст вредной привычки  Само совершенство  \
# 0                    False                            18.0              False
# 1                    False                             0.0              False
# 2                    False                            17.0              False
# 3                     True                            13.0              False
# 4                    False                            16.0              False
#
#    Активное или пассивное курение  Продолжительность сна
# 0                            True                    8.0
# 1                            True                    4.0
# 2                            True                    8.0
# 3                            True                    8.0
# 4                            True                    7.0

# %%
test_features = create_features(test, False)

# %%
test_features.shape
# Out:
# (638, 105)

# %%
test_features.head()
# Out:
#               ID  Пол - М  Семья - в браке в настоящее время  \
# 0  54-001-019-01    False                              False
# 1  54-002-133-01    False                              False
# 2  54-001-007-01    False                               True
# 3  54-102-116-01    False                               True
# 4  54-502-005-02     True                               True
#
#    Семья - в разводе  Семья - вдовец / вдова  \
# 0              False                    True
# 1               True                   False
# 2              False                   False
# 3              False                   False
# 4              False                   False
#
#    Семья - гражданский брак / проживание с партнером  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Семья - никогда не был(а) в браке  \
# 0                              False
# 1                              False
# 2                              False
# 3                              False
# 4                              False
#
#    Семья - раздельное проживание (официально не разведены)  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Семья - живет один  Этнос - европейская  Этнос - другая азиатская  \
# 0                True                 True                     False
# 1                True                 True                     False
# 2               False                 True                     False
# 3               False                 True                     False
# 4               False                 True                     False
#
#    Этнос - прочее  Национальность - Азербайджанцы  Национальность - Армяне  \
# 0           False                           False                    False
# 1           False                           False                    False
# 2           False                           False                    False
# 3           False                           False                    False
# 4           False                           False                    False
#
#    Национальность - Башкиры  Национальность - Белорусы  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    Национальность - Буряты  Национальность - Другие национальности  \
# 0                    False                                   False
# 1                    False                                   False
# 2                    False                                   False
# 3                    False                                   False
# 4                    False                                   False
#
#    Национальность - Евреи  Национальность - Казахи  Национальность - Киргизы  \
# 0                   False                    False                     False
# 1                   False                    False                     False
# 2                   False                    False                     False
# 3                   False                    False                     False
# 4                   False                    False                     False
#
#    Национальность - Лезгины  Национальность - Молдаване  \
# 0                     False                       False
# 1                     False                       False
# 2                     False                       False
# 3                     False                       False
# 4                     False                       False
#
#    Национальность - Мордва  Национальность - Немцы  Национальность - Русские  \
# 0                    False                   False                      True
# 1                    False                   False                      True
# 2                    False                   False                      True
# 3                    False                   False                      True
# 4                    False                   False                      True
#
#    Национальность - Таджики  Национальность - Татары  \
# 0                     False                    False
# 1                     False                    False
# 2                     False                    False
# 3                     False                    False
# 4                     False                    False
#
#    Национальность - Удмурты  Национальность - Украинцы  \
# 0                     False                      False
# 1                     False                      False
# 2                     False                      False
# 3                     False                      False
# 4                     False                      False
#
#    Национальность - Чуваши  Национальность - Эстонцы  \
# 0                    False                     False
# 1                    False                     False
# 2                    False                     False
# 3                    False                     False
# 4                    False                     False
#
#    Национальность - Азия / Кавказ  \
# 0                           False
# 1                           False
# 2                           False
# 3                           False
# 4                           False
#
#    Национальность - Русские / Белорусы / Украинцы  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
#
#    Религия - Атеист / агностик  Религия - Другое  Религия - Индуизм  \
# 0                        False             False              False
# 1                        False             False              False
# 2                        False             False              False
# 3                        False             False              False
# 4                        False             False              False
#
#    Религия - Ислам  Религия - Нет  Религия - Христианство  \
# 0            False          False                    True
# 1            False          False                    True
# 2            False          False                    True
# 3            False          False                    True
# 4            False          False                    True
#
#    Религия - Индуизм / Ислам / Другое  Религия - Верующий  \
# 0                               False                True
# 1                               False                True
# 2                               False                True
# 3                               False                True
# 4                               False                True
#
#    Образование - начальная школа  Образование - среднее  \
# 0                          False                   True
# 1                          False                  False
# 2                          False                  False
# 3                          False                  False
# 4                          False                   True
#
#    Образование - профессиональное училище  Образование - ВУЗ  \
# 0                                   False              False
# 1                                   False               True
# 2                                   False               True
# 3                                    True              False
# 4                                   False              False
#
#    Профессия - ведение домашнего хозяйства  Профессия - вооруженные силы  \
# 0                                    False                         False
# 1                                    False                         False
# 2                                    False                         False
# 3                                    False                         False
# 4                                    False                         False
#
#    Профессия - дипломированные специалисты  \
# 0                                    False
# 1                                     True
# 2                                     True
# 3                                    False
# 4                                    False
#
#    Профессия - квалифицированные работники сельского хозяйства и рыболовного  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Профессия - низкоквалифицированные работники  \
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                          True
# 4                                         False
#
#    Профессия - операторы и монтажники установок и машинного оборудования  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                               True
#
#    Профессия - законотворцы / менеджеры  Профессия - сфера обслуживания  \
# 0                                 False                           False
# 1                                 False                           False
# 2                                 False                           False
# 3                                 False                           False
# 4                                 False                           False
#
#    Профессия - ремесленники и представители других отраслей промышленности  \
# 0                                               True
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    Профессия - служащие  Профессия - техники и младшие специалисты  \
# 0                 False                                      False
# 1                 False                                      False
# 2                 False                                      False
# 3                 False                                      False
# 4                 False                                      False
#
#    Профессия - военные / служащие / управление  Профессия - промышленность  \
# 0                                        False                        True
# 1                                        False                       False
# 2                                        False                       False
# 3                                        False                       False
# 4                                        False                        True
#
#    Профессия - низкая квалификация  Вы работаете?  Выход на пенсию  \
# 0                            False           True            False
# 1                            False          False             True
# 2                            False          False             True
# 3                             True           True            False
# 4                            False          False             True
#
#    Прекращение работы по болезни  Сахарный диабет  Гепатит  Онкология  \
# 0                          False            False    False      False
# 1                          False            False    False      False
# 2                          False            False    False      False
# 3                          False            False     True      False
# 4                          False            False    False      False
#
#    Хроническое заболевание легких  Бронхиальная астма  Туберкулез легких  \
# 0                           False               False              False
# 1                           False               False              False
# 2                           False               False              False
# 3                           False               False              False
# 4                           False               False              False
#
#    ВИЧ/СПИД  Регулярный прием лекарственных средств  Травмы за год  Переломы  \
# 0     False                                    True           True      True
# 1     False                                    True          False     False
# 2     False                                    True          False     False
# 3     False                                   False          False      True
# 4     False                                    True           True      True
#
#    Статус Курения - Бросил(а)  Статус Курения - Курит  \
# 0                       False                   False
# 1                       False                   False
# 2                       False                   False
# 3                       False                   False
# 4                       False                    True
#
#    Статус Курения - Никогда не курил(а)  Пассивное курение  \
# 0                                  True              False
# 1                                  True              False
# 2                                  True              False
# 3                                  True              False
# 4                                 False              False
#
#    Алкоголь - никогда не употреблял  Алкоголь - ранее употреблял  \
# 0                             False                        False
# 1                             False                        False
# 2                             False                        False
# 3                              True                        False
# 4                             False                        False
#
#    Алкоголь - употребляю в настоящее время  Сон после обеда  Спорт клубы  \
# 0                                     True            False         True
# 1                                     True            False        False
# 2                                     True            False        False
# 3                                    False            False        False
# 4                                     True            False        False
#
#    Религия клубы  Возраст курения  Сигарет в день  Возраст алког  \
# 0           True              0.0             0.0           23.0
# 1          False              0.0             0.0           22.0
# 2          False              0.0             0.0           18.0
# 3          False              0.0             0.0            0.0
# 4          False             14.0            20.0           19.0
#
#    Образование - Уровень  Одинокий мужчина  Одинокая женщина  \
# 0                      3             False              True
# 1                      5             False              True
# 2                      5             False             False
# 3                      4             False             False
# 4                      3             False             False
#
#    Без работы и не на пенсии  Сигарет в день (сейчас)  Частота пасс кур  \
# 0                      False                      0.0               0.0
# 1                      False                      0.0               0.0
# 2                      False                      0.0               1.5
# 3                      False                      0.0               4.5
# 4                      False                     20.0               7.0
#
#    Болезнь легких  Инфекционная болезнь  Хроническая болезнь  \
# 0           False                 False                False
# 1           False                 False                False
# 2           False                 False                False
# 3           False                  True                 True
# 4           False                 False                False
#
#    Регулярный прием лекарственных средств без болезней из опроса  Больной  \
# 0                                               True                 True
# 1                                               True                 True
# 2                                               True                 True
# 3                                              False                 True
# 4                                               True                 True
#
#    Травмы / переломы  Идеальное здоровье  Без вредных привычек  \
# 0               True               False                 False
# 1              False               False                 False
# 2              False               False                 False
# 3               True               False                  True
# 4               True               False                 False
#
#    Бросил вредную привычку  Макс. возраст вредной привычки  Само совершенство  \
# 0                    False                            23.0              False
# 1                    False                            22.0              False
# 2                    False                            18.0              False
# 3                    False                             0.0              False
# 4                    False                            19.0              False
#
#    Активное или пассивное курение  Продолжительность сна
# 0                           False                    8.0
# 1                           False                    4.0
# 2                           False                    8.0
# 3                           False                    8.0
# 4                            True                    7.0
